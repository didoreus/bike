# %%
df = spark.read.table("circuitbike_dev.bronze.jc_citibike")
display(df)
# Out:
# DataFrame[file_path: string, load_time: timestamp, ride_id: string, rideable_type: string, started_at: string, ended_at: string, start_station_name: string, start_station_id: string, end_station_name: string, end_station_id: string, start_lat: string, start_lng: string, end_lat: string, end_lng: string, member_casual: string, metadata: map<string,string>]
